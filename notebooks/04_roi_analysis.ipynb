# %%
# Phase 4 - ROI Analysis: Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# Load data
df = pd.read_csv("../data/WA_Fn-UseC_-HR-Employee-Attrition.csv")
conn = sqlite3.connect("../data/hr_database.db")

# We will assume training cost per session = $500
# Industry standard for corporate training
TRAINING_COST_PER_SESSION = 500

print("ROI Analysis Ready!")
print("Assumed Training Cost per Session: $500")
print("Total Employees:", len(df))
